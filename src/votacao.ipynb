# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('https://github.com/dhaitz/matplotlib-stylesheets/raw/master/pitayasmoothie-light.mplstyle')

# %%
import matplotlib.pyplot as plt
import random

salvar_graficos = 1

nome_pasta = 'votacao'
n_dpi = 300
p = (10, 10)
p_color = (0, 0, 0)

# Coordenadas dos pontos originais
xs = [0.6, 0.7, 0.8, 0.9, 1]
ys = [0, 1, 2, 3, 4]
colors = [(24/255, 192/255, 196/255), (246/255, 33/255, 150/255), (162/255, 103/255, 245/255), (243/255, 144/255, 126/255), (255/255, 228/255, 107/255)]

n_img = 5
largura = 14/2.54
altura = 10/2.54

fig, axs = plt.subplots(1, 1, figsize=(largura, altura))
for i in range(0, n_img):
    axs.plot(xs[i], ys[i], 'o', color=colors[i], label=f'$({xs[i]};{ys[i]})$')
axs.set_xlabel('x')
axs.set_ylabel('y')

# Inverter o eixo x
axs.invert_xaxis()

# Ajustar os limites do eixo x e y para cobrir todos os pontos
axs.set_xlim(min(xs) - 0.02, max(xs) + 0.02)
axs.set_ylim(min(ys) - 0.2, max(ys) + 0.2)  # Aumentar o eixo y

plt.savefig(f'img/{nome_pasta}/{nome_pasta}{111}.png', dpi=n_dpi) if salvar_graficos else None

# %%
import matplotlib.pyplot as plt
import random

salvar_graficos = 1

nome_pasta = 'votacao'
n_dpi = 300
p = (10, 10)
p_color = (0, 0, 0)

# Coordenadas dos pontos originais
xs = [0.6, 0.7, 0.8, 0.9, 1, 0.65, 0.65, 0.7, 0.75, 0.75, 0.85, 0.85, 0.9, 1, 0.95]
ys = [0, 1, 2, 3, 4, 0.1, 1.2, 2.5, 0.5, 2.5, 3, 2, 4, 3.5, 2]
colors = [(24/255, 192/255, 196/255), (246/255, 33/255, 150/255), (162/255, 103/255, 245/255), (243/255, 144/255, 126/255), (255/255, 228/255, 107/255)]

# Gerar 10 pontos aleatórios e adicioná-los às listas existentes
for _ in range(10):
    new_color = (random.random(), random.random(), random.random())  # Gerar uma cor aleatória
    colors.append(new_color)

n_img = len(xs)  # Atualizar o número total de pontos

largura = 14/2.54
altura = 10/2.54

fig, axs = plt.subplots(1, 1, figsize=(largura, altura))

# Plotar os pontos existentes como marcadores individuais
for i in range(n_img):
    axs.plot(xs[i], ys[i], 'o', color=colors[i])



axs.set_xlabel('x')
axs.set_ylabel('y')

# Inverter o eixo x
axs.invert_xaxis()

# Ajustar os limites do eixo x e y para cobrir todos os pontos
axs.set_xlim(min(xs) - 0.02, max(xs) + 0.02)
axs.set_ylim(min(ys) - 0.2, max(ys) + 0.2)  # Aumentar o eixo y

plt.savefig(f'img/{nome_pasta}/{nome_pasta}{222}.png', dpi=n_dpi) if salvar_graficos else None

# %%
import matplotlib.pyplot as plt
import random

salvar_graficos = 1

nome_pasta = 'votacao'
n_dpi = 300
p = (10, 10)
p_color = (0, 0, 0)

# Coordenadas dos pontos originais
xs = [0.6, 0.7, 0.8, 0.9, 1, 0.65, 0.65, 0.7, 0.75, 0.75, 0.85, 0.85, 0.9, 1, 0.95]
ys = [0, 1, 2, 3, 4, 0.1, 1.2, 2.5, 0.5, 2.5, 3, 2, 4, 3.5, 2]

# Gerar 10 pontos aleatórios e adicioná-los às listas existentes
n_img = len(xs)  # Atualizar o número total de pontos

largura = 14/2.54
altura = 10/2.54

fig, axs = plt.subplots(1, 1, figsize=(largura, altura))

# Plotar os pontos existentes como marcadores individuais
for i in range(n_img):
    axs.plot(xs[i], ys[i], 'o', color=colors[i])


# Traçar uma reta entre os pontos inicial (x1, y1) e final (x2, y2)
axs.plot([0.6, 1], [0, 4], linestyle='-', color='black')

axs.set_xlabel('x')
axs.set_ylabel('y')

# Inverter o eixo x
axs.invert_xaxis()

# Ajustar os limites do eixo x e y para cobrir todos os pontos
axs.set_xlim(min(xs) - 0.02, max(xs) + 0.02)
axs.set_ylim(min(ys) - 0.2, max(ys) + 0.2)  # Aumentar o eixo y

plt.savefig(f'img/{nome_pasta}/{nome_pasta}{333}.png', dpi=n_dpi) if salvar_graficos else None

# %%
import matplotlib.pyplot as plt
import random

salvar_graficos = 1

nome_pasta = 'votacao'
n_dpi = 300
p = (10, 10)
p_color = (0, 0, 0)

# Coordenadas dos pontos originais
xs = [0.6, 0.7, 0.8, 0.9, 1, 0.65, 0.65, 0.7, 0.75, 0.75, 0.85, 0.85, 0.9, 1, 0.95]
ys = [0, 1, 2, 3, 4, 0.1, 1.2, 1.75, 1, 3, 3, 2, 4, 3.5, 3]
colors = [(24/255, 192/255, 196/255), (246/255, 33/255, 150/255), (162/255, 103/255, 245/255), (243/255, 144/255, 126/255), (255/255, 228/255, 107/255)]

# Gerar 10 pontos aleatórios e adicioná-los às listas existentes
for _ in range(10):
    new_color = (random.random(), random.random(), random.random())  # Gerar uma cor aleatória
    colors.append(new_color)

n_img = len(xs)  # Atualizar o número total de pontos

largura = 14/2.54
altura = 10/2.54

fig, axs = plt.subplots(1, 1, figsize=(largura, altura))

# Plotar os pontos existentes como marcadores individuais
for i in range(n_img):
    axs.plot(xs[i], ys[i], 'o', color=colors[i])

axs.set_xlabel('x')
axs.set_ylabel('y')

# Inverter o eixo x
axs.invert_xaxis()

# Ajustar os limites do eixo x e y para cobrir todos os pontos
axs.set_xlim(min(xs) - 0.02, max(xs) + 0.02)
axs.set_ylim(min(ys) - 0.2, max(ys) + 0.2)  # Aumentar o eixo y

plt.savefig(f'img/{nome_pasta}/{nome_pasta}{222}.png', dpi=n_dpi) if salvar_graficos else None

# %%
import matplotlib.pyplot as plt

salvar_graficos = 1

nome_pasta = 'votacao2'
n = 'tremido'
n_dpi = 300
p = (10,10)
p_color = (0,0,0)
n_img = 5

x1 = 0
x2 = 20

xs = [0.6, 0.7, 0.8, 0.9, 1]
ys = [0, 1.2, 1.9, 3.2, 4]
colors = [(24/255, 192/255, 196/255), (246/255, 33/255, 150/255), (162/255, 103/255, 245/255), (243/255, 144/255, 126/255), (255/255, 228/255, 107/255)]

largura = 14/2.54
altura = 10/2.54

fig, axs = plt.subplots(1, 1, figsize=(largura, altura))
for i in range(0, n_img):
    axs.plot(xs[i], ys[i], 'o', color=colors[i], label=f'$({xs[i]};{ys[i]})$')
axs.set_xlabel('x')
axs.set_ylabel('y')


# Inverter o eixo x
axs.invert_xaxis()

# Ajustar os limites do eixo x para cobrir todos os pontos
axs.set_xlim(xs[0] - 0.02, xs[-1] + 0.02)
axs.set_ylim(ys[0] - 0.2, ys[-1] + 0.2)

plt.savefig(f'img/{nome_pasta}/{nome_pasta}{n}.png', dpi=n_dpi) if salvar_graficos else None

# %%
import matplotlib.pyplot as plt

salvar_graficos = 1

nome_pasta = 'votacao2'
n = 'tremido2'
n_dpi = 300
p = (10,10)
p_color = (0,0,0)
n_img = 5

x1 = 0.6
x2 = 1

xs = [0.6, 0.7, 0.8, 0.9, 1]
ys = [0, 1.2, 1.9, 3.2, 4]
colors = [(24/255, 192/255, 196/255), (246/255, 33/255, 150/255), (162/255, 103/255, 245/255), (243/255, 144/255, 126/255), (255/255, 228/255, 107/255)]

largura = 14/2.54
altura = 10/2.54

fig, axs = plt.subplots(1, 1, figsize=(largura, altura))

# Plotar os pontos
for i in range(0, n_img):
    axs.plot(xs[i], ys[i], 'o', color=colors[i], label=f'$({xs[i]};{ys[i]})$')

# Traçar uma reta entre os pontos inicial (x1, y1) e final (x2, y2)
axs.plot([x1, x2], [ys[0], ys[-1]], linestyle='-', color='black')

axs.set_xlabel('x')
axs.set_ylabel('y')

# Inverter o eixo x
axs.invert_xaxis()

# Ajustar os limites do eixo x e y para cobrir todos os pontos
axs.set_xlim(xs[0] - 0.02, xs[-1] + 0.02)
axs.set_ylim(ys[0] - 0.2, ys[-1] + 0.2)

plt.savefig(f'img/{nome_pasta}/{nome_pasta}{n}.png', dpi=n_dpi) if salvar_graficos else None

# %%
import matplotlib.pyplot as plt

salvar_graficos = 1

nome_pasta = 'votacao3'
n = 1
n_dpi = 300
p = (8,-5)
p_color = (0,0,0)
n_img = 1

x1 = -100
x2 = 100

y1 = -100
y2 = 100

xs = [-0.6, -0.7, -0.8, -0.9, -1]
ys = [0, 1.2, 1.9, 3.2, 4]
colors = [(24/255, 192/255, 196/255), (246/255, 33/255, 150/255), (162/255, 103/255, 245/255), (243/255, 144/255, 126/255), (255/255, 228/255, 107/255)]

largura = 14/2.54
altura = 10/2.54

# %%
plt.figure(figsize=(largura, altura))
for i in range(0,n_img):
    plt.plot([x1,x2], [x1*xs[i]+ys[i],x2*xs[i]+ys[i]], color=colors[i], label=f'$n={xs[i]}m+{ys[i]}$')
plt.xlabel('m')
plt.ylabel('n')
plt.legend()
plt.xlim(x1,x2)
plt.ylim(y1,y2)
plt.savefig(f'img/{nome_pasta}/{nome_pasta}{n_img}.png', dpi=n_dpi)
n_img += 1

# %%
plt.figure(figsize=(largura, altura))
for i in range(0,n_img):
    plt.plot([x1,x2], [x1*xs[i]+ys[i],x2*xs[i]+ys[i]], color=colors[i], label=f'$n={xs[i]}m+{ys[i]}$')
plt.xlabel('m')
plt.ylabel('n')
plt.legend()
plt.xlim(x1,x2)
plt.ylim(y1,y2)
plt.savefig(f'img/{nome_pasta}/{nome_pasta}{n_img}.png', dpi=n_dpi)
n_img += 1

# %%
plt.figure(figsize=(largura, altura))
for i in range(0,n_img):
    plt.plot([x1,x2], [x1*xs[i]+ys[i],x2*xs[i]+ys[i]], color=colors[i], label=f'$n={xs[i]}m+{ys[i]}$')
plt.xlabel('m')
plt.ylabel('n')
plt.legend()
plt.xlim(x1,x2)
plt.ylim(y1,y2)
plt.savefig(f'img/{nome_pasta}/{nome_pasta}{n_img}.png', dpi=n_dpi)
n_img += 1

# %%
plt.figure(figsize=(largura, altura))
for i in range(0,n_img):
    plt.plot([x1,x2], [x1*xs[i]+ys[i],x2*xs[i]+ys[i]], color=colors[i], label=f'$n={xs[i]}m+{ys[i]}$')
plt.xlabel('m')
plt.ylabel('n')
plt.legend()
plt.xlim(x1,x2)
plt.ylim(y1,y2)
plt.savefig(f'img/{nome_pasta}/{nome_pasta}{n_img}.png', dpi=n_dpi)
n_img += 1

# %%
plt.figure(figsize=(largura, altura))
for i in range(0,n_img):
    plt.plot([x1,x2], [x1*xs[i]+ys[i],x2*xs[i]+ys[i]], color=colors[i], label=f'$n={xs[i]}m+{ys[i]}$')
plt.xlabel('m')
plt.ylabel('n')
plt.legend()
plt.xlim(x1,x2)
plt.ylim(y1,y2)
plt.savefig(f'img/{nome_pasta}/{nome_pasta}{n_img}.png', dpi=n_dpi)

# %%
nome_pasta = 'votacao'

p = (8,-5)
plt.figure(figsize=(largura, altura))
for i in range(0,n_img):
    plt.plot([x1,x2], [x1*xs[i]+ys[i],x2*xs[i]+ys[i]], color=colors[i], label=f'$n={xs[i]}m+{ys[i]}$')
plt.plot(p[0], p[1],'o', color=p_color)
plt.xlabel('m')
plt.ylabel('n')
plt.legend()
plt.xlim(x1,x2)
plt.ylim(y1,y2)
plt.savefig(f'img/{nome_pasta}/{nome_pasta}{6}.png', dpi=n_dpi)

# %%
nome_pasta = 'votacao'


x1 = 8
x2 = 12

y1 = -8
y2 = -2


plt.figure(figsize=(largura, altura))
for i in range(0,n_img):
    plt.plot([x1,x2], [x1*xs[i]+ys[i],x2*xs[i]+ys[i]], color=colors[i], label=f'$n={xs[i]}m+{ys[i]}$')

plt.xlabel('m')
plt.ylabel('n')
plt.legend()
plt.xlim(x1,x2)
plt.ylim(y1,y2)
plt.savefig(f'img/{nome_pasta}/{nome_pasta}{7}.png', dpi=n_dpi)

# %%
nome_pasta = 'votacao'


x1 = 8
x2 = 12

y1 = -8
y2 = -2

plt.figure(figsize=(largura, altura))
for i in range(0,n_img):
    plt.plot([x1,x2], [x1*xs[i]+ys[i],x2*xs[i]+ys[i]], color=colors[i], label=f'$n={xs[i]}m+{ys[i]}$')


xq = [9.5, 10, 10, 9.5, 9.5]
yq = [-6, -6, -5, -5, -6]

plt.plot(xq , yq , color=p_color)

plt.xlabel('m')
plt.ylabel('n')
plt.legend()
plt.xlim(x1,x2)
plt.ylim(y1,y2)
plt.savefig(f'img/{nome_pasta}/{nome_pasta}{8}.png', dpi=n_dpi)

# %%
nome_pasta = 'votacao'


x1 = 8
x2 = 12

y1 = -8
y2 = -2

plt.figure(figsize=(largura, altura))
for i in range(0,n_img):
    plt.plot([x1,x2], [x1*xs[i]+ys[i],x2*xs[i]+ys[i]], color=colors[i], label=f'$n={xs[i]}m+{ys[i]}$')


xq = [9.5, 10, 10, 9.5, 9.5]
yq = [-6, -6, -5, -5, -6]

texto = "1"
pos_x = 9.6  # Posição X do texto
pos_y = -5.2  # Posição Y do texto

plt.text(pos_x, pos_y, texto, ha='center', va='center', fontsize=12)
plt.plot(xq , yq , color=p_color)

xq2 = [10.5, 10, 10, 10.5, 10.5]
yq2 = [-6, -6, -5, -5, -6]

texto2 = "2"
pos_x2 = 10.1  # Posição X do texto
pos_y2 = -5.2  # Posição Y do texto

plt.text(pos_x2, pos_y2, texto2, ha='center', va='center', fontsize=12)

plt.plot(xq2 , yq2 , color=p_color)


xq3 = [9.5, 10, 10, 9.5, 9.5]
yq3 = [-6, -6, -7, -7, -6]

texto3 = "3"
pos_x3 = 9.6  # Posição X do texto
pos_y3 = -6.2  # Posição Y do texto

plt.text(pos_x3, pos_y3, texto3, ha='center', va='center', fontsize=12)

plt.plot(xq3 , yq3 , color=p_color)

plt.xlabel('m')
plt.ylabel('n')
plt.legend()
plt.xlim(x1,x2)
plt.ylim(y1,y2)
plt.savefig(f'img/{nome_pasta}/{nome_pasta}{9}.png', dpi=n_dpi)
